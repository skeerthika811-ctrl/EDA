# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Cleaned ShopifyData.csv")
df
# Out:
#             date      date.1       open       high        low      close  \
# 0     2015-05-21  2015-05-21   2.800000   2.874000   2.411000   2.568000
# 1     2015-05-22  2015-05-22   2.607000   3.110000   2.600000   2.831000
# 2     2015-05-26  2015-05-26   2.980000   3.034000   2.908000   2.965000
# 3     2015-05-27  2015-05-27   3.067000   3.081000   2.700000   2.750000
# 4     2015-05-28  2015-05-28   2.755000   2.774000   2.648000   2.745000
# ...          ...         ...        ...        ...        ...        ...
# 2464  2025-03-10  2025-03-10  96.070000  96.186996  91.690002  92.750000
# 2465  2025-03-11  2025-03-11  92.750000  95.109001  91.150002  92.949997
# 2466  2025-03-12  2025-03-12  96.669998  99.135002  95.290001  96.529999
# 2467  2025-03-13  2025-03-13  95.169998  95.529999  89.099998  90.589996
# 2468  2025-03-14  2025-03-14  94.610001  95.830002  93.059998  94.849998
#
#       adj_close     volume  Daily_Price_Change  Daily_Return
# ...

# %%
df.head()
# Out:
#          date      date.1   open   high    low  close  adj_close     volume  \
# 0  2015-05-21  2015-05-21  2.800  2.874  2.411  2.568      2.568  123039000
# 1  2015-05-22  2015-05-22  2.607  3.110  2.600  2.831      2.831   28412000
# 2  2015-05-26  2015-05-26  2.980  3.034  2.908  2.965      2.965    8202000
# 3  2015-05-27  2015-05-27  3.067  3.081  2.700  2.750      2.750    7976000
# 4  2015-05-28  2015-05-28  2.755  2.774  2.648  2.745      2.745    4000000
#
#    Daily_Price_Change  Daily_Return
# 0              -0.232     -8.285710
# 1               0.224      8.592250
# 2              -0.015     -0.503359
# 3              -0.317    -10.335830
# 4              -0.010     -0.362985

# %%
df.tail()
# Out:
#             date      date.1       open       high        low      close  \
# 2464  2025-03-10  2025-03-10  96.070000  96.186996  91.690002  92.750000
# 2465  2025-03-11  2025-03-11  92.750000  95.109001  91.150002  92.949997
# 2466  2025-03-12  2025-03-12  96.669998  99.135002  95.290001  96.529999
# 2467  2025-03-13  2025-03-13  95.169998  95.529999  89.099998  90.589996
# 2468  2025-03-14  2025-03-14  94.610001  95.830002  93.059998  94.849998
#
#       adj_close    volume  Daily_Price_Change  Daily_Return
# 2464  92.750000  16385300           -3.320000     -3.455813
# 2465  92.949997  12127100            0.199997      0.215630
# 2466  96.529999   8531900           -0.139999     -0.144822
# 2467  90.589996  11076400           -4.580002     -4.812443
# 2468  94.849998   7060700            0.239998      0.253671

# %%
df.set_index(df["date"])
# Out:
#                   date      date.1       open       high        low  \
# date
# 2015-05-21  2015-05-21  2015-05-21   2.800000   2.874000   2.411000
# 2015-05-22  2015-05-22  2015-05-22   2.607000   3.110000   2.600000
# 2015-05-26  2015-05-26  2015-05-26   2.980000   3.034000   2.908000
# 2015-05-27  2015-05-27  2015-05-27   3.067000   3.081000   2.700000
# 2015-05-28  2015-05-28  2015-05-28   2.755000   2.774000   2.648000
# ...                ...         ...        ...        ...        ...
# 2025-03-10  2025-03-10  2025-03-10  96.070000  96.186996  91.690002
# 2025-03-11  2025-03-11  2025-03-11  92.750000  95.109001  91.150002
# 2025-03-12  2025-03-12  2025-03-12  96.669998  99.135002  95.290001
# 2025-03-13  2025-03-13  2025-03-13  95.169998  95.529999  89.099998
# 2025-03-14  2025-03-14  2025-03-14  94.610001  95.830002  93.059998
#
#                 close  adj_close     volume  Daily_Price_Change  Daily_Return
# date
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["open"], label="Open")

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["high"], label="High")

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["low"], label="Low")

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["close"], label="Close")

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["open"], label="Open",color = "blue")
plt.plot(df.index, df["high"], label="High",color = "yellow")
plt.plot(df.index, df["low"], label="Low",color = "purple")
plt.plot(df.index, df["close"], label="Close",color = "green")

plt.title("Shopify Stock Prices Over Time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df.index, df["volume"])

plt.title("Shopify Trading Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Trading Volume")

plt.xticks(rotation=45)
plt.show()

# %%
df["SMA_20"] = df["close"].rolling(window=20).mean()
df["SMA_50"] = df["close"].rolling(window=50).mean()
print(df[["close","SMA_20","SMA_50"]].head(55))
# Out:
#     close   SMA_20   SMA_50
# 0   2.568      NaN      NaN
# 1   2.831      NaN      NaN
# 2   2.965      NaN      NaN
# 3   2.750      NaN      NaN
# 4   2.745      NaN      NaN
# 5   2.720      NaN      NaN
# 6   2.733      NaN      NaN
# 7   2.695      NaN      NaN
# 8   2.744      NaN      NaN
# 9   2.678      NaN      NaN
# 10  2.739      NaN      NaN
# 11  2.698      NaN      NaN
# 12  2.834      NaN      NaN
# 13  2.810      NaN      NaN
# 14  3.073      NaN      NaN
# 15  3.363      NaN      NaN
# 16  3.550      NaN      NaN
# 17  3.811      NaN      NaN
# 18  3.863      NaN      NaN
# 19  3.555  2.98625      NaN
# 20  3.552  3.03545      NaN
# 21  3.694  3.07860      NaN
# 22  3.543  3.10750      NaN
# 23  3.596  3.14980      NaN
# 24  3.484  3.18675      NaN
# 25  3.352  3.21835      NaN
# 26  3.132  3.23830      NaN
# 27  3.395  3.27330      NaN
# 28  3.111  3.29165      NaN
# 29  3.131  3.31430      NaN
# 30  3.053  3.33000      NaN
# 31  3.076  3.34890      NaN
# ...

# %%
df["SMA_20"] = df["close"].rolling(window=20).mean()
df["SMA_50"] = df["close"].rolling(window=50).mean()
print(df[["close","SMA_20","SMA_50"]].head(55))
# Out:
#     close   SMA_20   SMA_50
# 0   2.568      NaN      NaN
# 1   2.831      NaN      NaN
# 2   2.965      NaN      NaN
# 3   2.750      NaN      NaN
# 4   2.745      NaN      NaN
# 5   2.720      NaN      NaN
# 6   2.733      NaN      NaN
# 7   2.695      NaN      NaN
# 8   2.744      NaN      NaN
# 9   2.678      NaN      NaN
# 10  2.739      NaN      NaN
# 11  2.698      NaN      NaN
# 12  2.834      NaN      NaN
# 13  2.810      NaN      NaN
# 14  3.073      NaN      NaN
# 15  3.363      NaN      NaN
# 16  3.550      NaN      NaN
# 17  3.811      NaN      NaN
# 18  3.863      NaN      NaN
# 19  3.555  2.98625      NaN
# 20  3.552  3.03545      NaN
# 21  3.694  3.07860      NaN
# 22  3.543  3.10750      NaN
# 23  3.596  3.14980      NaN
# 24  3.484  3.18675      NaN
# 25  3.352  3.21835      NaN
# 26  3.132  3.23830      NaN
# 27  3.395  3.27330      NaN
# 28  3.111  3.29165      NaN
# 29  3.131  3.31430      NaN
# 30  3.053  3.33000      NaN
# 31  3.076  3.34890      NaN
# ...

# %%
plt.figure(figsize=(12,6))

plt.plot(df.index, df["close"],label="Close Price")
plt.plot(df.index, df["SMA_20"],label="20-Day SMA")
plt.plot(df.index, df["SMA_50"],label="50-Day SMA")

plt.title("Shopify Closing Price with Moving Averages")
plt.xlabel("Date")
plt.xlabel("Price")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(df.index, df["close"],label="Close Price")
plt.plot(df.index, df["SMA_20"],label="20-Day SMA")
plt.plot(df.index, df["SMA_50"],label="50-Day SMA")

plt.title("Shopify Closing Price with Moving Averages")
plt.xlabel("Date")
plt.xlabel("Price")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["volume"],df["Daily_Price_Change"])
plt.title("Trading Volume")
plt.xlabel("Daily Price Change")
plt.show()

# %%
print("Mean Return",df["Daily_Return"].mean())
print("Variance",df["Daily_Return"].var())
print("Standard Deviation",df["Daily_Return"].std())
# Out:
# Mean Return 0.08640631099421996
# Variance 9.733081984179552
# Standard Deviation 3.1197887723657756

# %%
print("Mean Return",df["Daily_Return"].mean())
print("Variance",df["Daily_Return"].var())
print("Standard Deviation",df["Daily_Return"].std())
# Out:
# Mean Return 0.08640631099421996
# Variance 9.733081984179552
# Standard Deviation 3.1197887723657756

# %%
plt.figure(figsize=(8, 5))

sns.kdeplot(df["Daily_Return"], fill=True)

plt.title("KDE Plot of Shopify Daily Returns")
plt.xlabel("Daily Return (%)")

plt.show()

# %%
threshold = df["Daily_Return"].abs().quantile(0.90)

high_volatility = df[
    df["Daily_Return"].abs() >= threshold
]

print(high_volatility[
    ["close", "Daily_Return"]
])
# Out:
#            close  Daily_Return
# 0       2.568000     -8.285710
# 1       2.831000      8.592250
# 3       2.750000    -10.335830
# 12      2.834000      6.381384
# 14      3.073000      7.862407
# ...          ...           ...
# 2423  106.779999     -7.067017
# 2436  117.449997      7.752291
# 2448  127.650002      5.495869
# 2453  115.559998     -7.699680
# 2459  106.580002     -5.589510
#
# [247 rows x 2 columns]
